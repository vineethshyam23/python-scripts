# %%
import pandas as pd
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns

# Read in price data
df = pd.read_csv("C:/Users/svi02/Documents/Python Scripts/PyPortfolioOpt-master/tests/stock_prices.csv", parse_dates=True, index_col="date")

# Calculate expected returns and sample covariance
mu = expected_returns.mean_historical_return(df)
S = risk_models.sample_cov(df)

# Optimise for maximal Sharpe ratio
ef = EfficientFrontier(mu, S)
raw_weights = ef.max_sharpe()
cleaned_weights = ef.clean_weights()
ef.save_weights_to_file("C:/Users/svi02/Documents/Python Scripts/PyPortfolioOpt-master/tests/weights.csv")  # saves to file
print(cleaned_weights)
ef.portfolio_performance(verbose=True)
# Out:
# {'GOOG': 0.01258, 'AAPL': 0.09203, 'FB': 0.19857, 'BABA': 0.09642, 'AMZN': 0.07154, 'GE': 0.0, 'AMD': 0.0, 'WMT': 0.0, 'BAC': 0.0, 'GM': 0.0, 'T': 0.0, 'UAA': 0.0, 'SHLD': 0.0, 'XOM': 0.0, 'RRC': 0.0, 'BBY': 0.06129, 'MA': 0.24566, 'PFE': 0.18422, 'JPM': 0.0, 'SBUX': 0.03768}
# Expected annual return: 33.0%
# Annual volatility: 21.7%
# Sharpe Ratio: 1.43
# C:\Anaconda\lib\site-packages\cvxpy-1.1.0a3-py3.6-win-amd64.egg\cvxpy\expressions\expression.py:503: DeprecationWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, DeprecationWarning)
# (0.33035037367760506, 0.21671276571944567, 1.4320816434015786)

# %%
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices


latest_prices = get_latest_prices(df)
weights = ef.max_sharpe()
weights

da = DiscreteAllocation(weights, latest_prices, total_portfolio_value=10000)
# allocation, leftover = da.lp_portfolio()
# print("Discrete allocation:", allocation)
# print("Funds remaining: ${:.2f}".format(leftover))
# Out:
# C:\Anaconda\lib\site-packages\cvxpy-1.1.0a3-py3.6-win-amd64.egg\cvxpy\expressions\expression.py:503: DeprecationWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, DeprecationWarning)

# %%
da.lp_portfolio()

# %%
import pandas as pd
import numpy as np
import cvxpy as cp
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import EfficientFrontier
from pypfopt import objective_functions
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices
from pypfopt import HRPOpt
from pypfopt import CLA
from pypfopt import black_litterman
from pypfopt import BlackLittermanModel
from pypfopt import Plotting


# Reading in the data; preparing expected returns and a risk model
df = pd.read_csv("C:/Users/svi02/Documents/Python Scripts/PyPortfolioOpt-master/tests/stock_prices.csv", parse_dates=True, index_col="date")
returns = df.pct_change().dropna()
mu = expected_returns.mean_historical_return(df)
S = risk_models.sample_cov(df)

# Long-only Maximum Sharpe portfolio, with discretised weights
ef = EfficientFrontier(mu, S)
weights = ef.max_sharpe()
ef.portfolio_performance(verbose=True)
latest_prices = get_latest_prices(df)

da = DiscreteAllocation(weights, latest_prices)
allocation, leftover = da.lp_portfolio()
print("Discrete allocation:", allocation)
print("Funds remaining: ${:.2f}".format(leftover))
# Out:
# C:\Anaconda\lib\site-packages\cvxpy-1.1.0a3-py3.6-win-amd64.egg\cvxpy\expressions\expression.py:503: DeprecationWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, DeprecationWarning)
# C:\Anaconda\lib\site-packages\cvxpy-1.1.0a3-py3.6-win-amd64.egg\cvxpy\expressions\expression.py:503: DeprecationWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
# ...

# %%
from nltk.corpus import wordnet

dog = wordnet.synset('cancel.n.01')
print(dog.lemma_names())
# Out:
# ['natural', 'cancel']

# %%
from PyDictionary import PyDictionary 
dictionary=PyDictionary() 
print (dictionary.synonym("dog"))
# Out:
# dog has no Synonyms in the API
# None
# C:\Anaconda\lib\site-packages\PyDictionary\utils.py:5: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 5 of the file C:\Anaconda\lib\site-packages\PyDictionary\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   return BeautifulSoup(requests.get(url).text)
# C:\Anaconda\lib\site-packages\bs4\builder\_lxml.py:287: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   self.parser.feed(markup)
