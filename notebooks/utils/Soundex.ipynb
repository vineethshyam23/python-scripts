# %%
# !pip install fuzzy
# Out:
# ...
#   Created wheel for fuzzy: filename=Fuzzy-1.2.2-cp38-cp38-win_amd64.whl size=47489 sha256=545e8fa78fb5b2fe21f5be1226d1ebfd206d6394340b609992f08780140168bc
#   Stored in directory: c:\users\svi02\appdata\local\pip\cache\wheels\f0\ce\e6\8d687ffcfd755ea572dc3cfd1f4d1f93027785da4c52615f47
# Successfully built fuzzy
# ...

# %%
import fuzzy
soundex = fuzzy.Soundex(4)
soundex('Vineeth')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-7db795c9cb1b> in <module>
#       1 import fuzzy
# ----> 2 soundex = fuzzy.Soundex()
#       3 soundex('Vineeth')
#
# src\fuzzy.pyx in fuzzy.Soundex.__init__()
#
# TypeError: __init__() takes exactly 1 positional argument (0 given)

# %%
# !pip install jellyfish

# %%
import jellyfish
jellyfish.soundex("hilton")
# Out:
# 'H435'

# %%
jellyfish.soundex("heilden")
# Out:
# 'H435'
