# %%
import pandas as pd

df_1 = pd.read_excel('C:/Users/USER/Documents/misc/TargetVSOffer_rates_hotels.xlsx',
                       sheet_name='Target_rates_wo_outliers', 
                       encoding='utf-8')
df_1.head()

# %%
df_2 = pd.read_excel('C:/Users/USER/Documents/misc/bidrate_mp_hotels_list.xls',
                       sheet_name='Grid Results', 
                       encoding='utf-8')
df_2.head()

# %%
res_df = pd.merge(left=df_1, 
                  right=df_2, 
                  on='HOTEL_ID',
                  # right_on = '',
                  # left_on = '',
                  how='right')
res_df.shape

# %%
res_df.to_excel('C:\\Users\\USER\\Documents\\misc\\BidVSOffer_rates_hotels_new.xlsx', 
            sheet_name='TR_BBR', 
            header=True, 
            encoding='utf-8', 
            index=False, 
            freeze_panes=(1,1))

# %% [markdown]
# THE END
