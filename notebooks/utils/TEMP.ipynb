# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\svi02\\Documents\\CXL_CLUSTER.CSV" , 
                 sep=';',
                 header=0                    
                   )
df.shape
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-1-bdc019f3cee3> in <module>()
#       2 df = pd.read_csv("C:\\Users\\svi02\\Documents\\CXL_CLUSTER.CSV" ,
#       3                  sep=';',
# ----> 4                  header=0
#       5                    )
#       6 df.shape
#
# ...

# %%
df.head()
# Out:
#    HOTEL_ID                          HOTEL_NAME  CHAIN INFO  \
# 0         1                        Savoy Berlin         NaN
# 1         2      Berlin Plaza Am Kurfürstendamm         NaN
# 2         3                   Wyndham Excelsior         NaN
# 3         4                   ibis Berlin Messe         NaN
# 4         5  Mercure Airport Hotel Berlin Tegel         NaN
#
#    HOTEL_CHAIN_COVERAGE_ID HOTEL_CHAIN_COVERAGE_NAME  HOTEL_CHAIN_ID  \
# 0                        2                  Regional             237
# 1                        0                Individual              -1
# 2                        0                Individual              -1
# 3                        1                    Global             550
# 4                        1                    Global             550
#
#   HOTEL_CHAIN_NAME  HOTEL_BRAND_ID  HOTEL_BRAND_NAME  LOCATION INFO  ...  \
# 0      WorldHotels             237       WorldHotels            NaN  ...
# ...

# %%
df = df.dropna(axis='columns')

# %%
df.head()
# Out:
#    HOTEL_ID  HOTEL_CHAIN_COVERAGE_ID HOTEL_CHAIN_COVERAGE_NAME  \
# 0         1                        2                  Regional
# 1         2                        0                Individual
# 2         3                        0                Individual
# 3         4                        1                    Global
# 4         5                        1                    Global
#
#    HOTEL_CHAIN_ID HOTEL_CHAIN_NAME  HOTEL_BRAND_ID  HOTEL_BRAND_NAME  \
# 0             237      WorldHotels             237       WorldHotels
# 1              -1       individual              -1              n.a.
# 2              -1       individual              -1              n.a.
# 3             550            Accor            1464     IBIS Standard
# 4             550            Accor            1461  Mercure by Accor
#
#    HOTEL_CITY_ID HOTEL_CITY_NAME  HOTEL_COUNTRY_ID HOTEL_COUNTRY_NAME  \
# 0          55133          Berlin                33            Germany
# ...

# %%
df_sub = df.head(300000)

# %%
df_sub.to_csv('C:\\Users\\svi02\\Downloads\\Hotel_content_report_test.csv', 
          sep = ',', 
          header = True,
          encoding='utf-8',
          index=False)

# %%
import os
file_size = os.path.getsize("C:\\Users\\svi02\\Downloads\\Hotel_content_report_test.csv")
file_size = file_size/(1024*1024.0)
file_size
# Out:
# 37.798855781555176
