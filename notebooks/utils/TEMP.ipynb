# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\USER\\Documents\\CXL_CLUSTER.CSV" , 
                 sep=';',
                 header=0                    
                   )
df.shape

# %%
df.head()

# %%
df = df.dropna(axis='columns')

# %%
df.head()

# %%
df_sub = df.head(300000)

# %%
df_sub.to_csv('C:\\Users\\USER\\Downloads\\Hotel_content_report_test.csv', 
          sep = ',', 
          header = True,
          encoding='utf-8',
          index=False)

# %%
import os
file_size = os.path.getsize("C:\\Users\\USER\\Downloads\\Hotel_content_report_test.csv")
file_size = file_size/(1024*1024.0)
file_size
