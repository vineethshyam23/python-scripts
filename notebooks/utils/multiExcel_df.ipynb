# %%
import pandas as pd

xls = pd.ExcelFile(r'C:\Users\svi02\Documents\misc\erfp_green.xls')
sheet_name = xls.sheet_names
sheet_name
# Out:
# ['Grid Results 1',
#  'Grid Results 2',
#  'Grid Results 3',
#  'Grid Results 4',
#  'Grid Results 5',
#  'Grid Results 6',
#  'Grid Results 7',
#  'Grid Results 8',
#  'Grid Results 9',
#  'Grid Results 10']

# %%
df=pd.read_excel(filename,
              sheet_name=None, 
              encoding='utf-8')

# %%
df.keys()
# Out:
# odict_keys(['Grid Results 1', 'Grid Results 2', 'Grid Results 3', 'Grid Results 4', 'Grid Results 5', 'Grid Results 6', 'Grid Results 7', 'Grid Results 8', 'Grid Results 9', 'Grid Results 10'])

# %%
df = pd.concat(df[frame] for frame in df.keys())
df.shape
# Out:
# (622579, 2)

# %%
df_na = df.dropna(axis = 0, how ='any')

# %%
df_new = df_na[df_na['STRING_VALUE'].str.contains('[\w]')]

# %%
df_new
# Out:
#                                             STRING_VALUE  count(*)
# 0                                                      Y   1289404
# 1                                                      N    938529
# 4                                                    Yes    220301
# 5                                                      0    217701
# 6                                                      B    175165
# 7                                                     No    129546
# 8                                          00:00 - 23:59     80640
# 10                                                     F     67130
# 11                                                    RT     60625
# 12                                           00:00-23:59     54009
# 13                                                    YX     51188
# 14                                                    HI     51093
# 15                                                     1     48087
# ...

# %%
df_new[df_new.count_number >= 6]
# Out:
#                                            string_value  count_number
# 0                                                     Y       1289404
# 1                                                     N        938529
# 4                                                   Yes        220301
# 6                                                     B        175165
# 7                                                    No        129546
# 8                                         00:00 - 23:59         80640
# 10                                                    F         67130
# 11                                                   RT         60625
# 12                                          00:00-23:59         54009
# 13                                                   YX         51188
# 14                                                   HI         51093
# 16                                                    D         47686
# ...

# %%
df_new.to_excel(r'C:\Users\svi02\Documents\misc\green_hotels_clean.xlsx')
