# %%
import pyexasol
import configparser

#Location of the ini file
config = configparser.ConfigParser()
config.read('C:\\Users\\USER\\.spyder-py3\\pfxPROD.ini')

# %%
dsn=config['pfxPROD']['dsn']
user=config['pfxPROD']['user']
pwd=config['pfxPROD']['pwd']
schema=config['pfxPROD']['schema']
dsn

# %%
# Exasol connection
connect = pyexasol.connect(dsn=dsn, user=user, password=pwd, schema=schema)

# %%
sql_query =  input("Please enter the query: ")

# %%
sql_query = """SELECT * FROM DWHPFX.FAK_PFX_HOTEL_RESULT_MP_CLOSED 


"""
QUERY = connect.execute(sql_query)

# %%
# Importing data into a DataFrame
import pandas as pd
df = connect.export_to_pandas(sql_query)
display(df.head())

# %%
display(df.info())

# %%
df.to_csv('C:\\Users\\USER\\Downloads\\test.csv', 
          sep = ',', 
          header = True,
          encoding='utf-8',
          index=False)

# %%
from datetime import date
df.to_excel('C:\\Users\\USER\\Documents\MP hunting list\\'+str(date.today())+'_MP_hunting_list.xlsx', 
              sheet_name='Sheet1', 
              header=True,
              encoding='utf-8',
              index=False,
              freeze_panes=(1,0) )
