# %%
import pyexasol
import configparser

#Location of the ini file
config = configparser.ConfigParser()
config.read('C:\\Users\\USER\\.spyder-py3\\ExasolPROD.ini')
dsn=config['exasolPROD']['dsn']
user=config['exasolPROD']['user']
pwd=config['exasolPROD']['pwd']
schema=config['exasolPROD']['schema']
# Exasol connection
connect = pyexasol.connect(dsn=dsn, user=user, password=pwd, schema=schema)

# %%
import time
start_time = time.time()

import_script = 'C:\\Users\\USER\\Documents\\Hotel_content_report\\hotel_content_report_exa.sql'

script_open = open(import_script, 'r')
script_read = script_open.read()
#file_read
df = connect.export_to_pandas(script_read)
df.HOTEL_ID.count()
end_time = time.time()
print("--- %s seconds ---" % (end_time - start_time))

# %%
import pandas as pd
HCR_df_ex = pd.read_excel("C:\\Users\\USER\\Documents\\Hotel_content_report\\20190612_HRS_Hotel_content_report.xlsx" ,
                   sheet_name = 'All excl. deleted',
                   usecols = "A,AR:AS",
                   header=0)
# HCR_df_ex_sub = HCR_df_ex[['HOTEL_ID', 'Destination RNs spelled out 2018', 'Invitations 2018']]
HCR_df_ex.head()

# %%
HCR_df = pd.merge(left=df, 
                  right=HCR_df_ex_sub, 
                  on='HOTEL_ID', 
                  # right_on = ''
                  # left_on = ''
                  how='left')

# %%
df = df[df['HOTEL_STATUS']!='deleted']
df.count()

# %%
from datetime import date
today = date.today()
start_time = time.time()

df.to_excel('C:\\Users\\USER\\Documents\\Hotel_content_report\\'+str(today).replace('-','')+'_HRS_Hotel_content_report.xlsx', 
            sheet_name='All excl. deleted', 
            header=True, 
            encoding='utf-8', 
            index=False, 
            freeze_panes=(1,1))
# HCR_df.to_csv('C:\\Users\\USER\\Documents\\Hotel_content_report\\'+str(today).replace('-','')+'_HRS_Hotel_content_report.csv', 
#           sep = ',', 
#           header = True,
#           encoding='utf-8',
#           index=False)
end_time = time.time()
print("--- %s seconds ---" % (end_time - start_time))

# %%
df.count()
