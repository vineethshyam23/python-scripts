# %%
import pyodbc
import pymssql
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'MicroStrategy ODBC Driver for Informix Wire Protocol',
#  'MicroStrategy ODBC Driver for Sybase ASE Wire Protocol',
#  'MicroStrategy ODBC Driver for Oracle Wire Protocol',
#  'MicroStrategy ODBC Driver for DB2 Wire Protocol',
#  'MicroStrategy ODBC Driver for PostgreSQL Wire Protocol',
#  'MicroStrategy ODBC Driver for Greenplum Wire Protocol',
#  'MicroStrategy ODBC Driver for Salesforce',
#  'MicroStrategy ODBC Driver for Apache Hive Wire Protocol',
#  'MicroStrategy ODBC Driver for Impala Wire Protocol',
#  'MicroStrategy ODBC Driver for SQL Server Wire Protocol',
#  'MicroStrategy ODBC Driver for MongoDB',
#  'MicroStrategy ODBC Driver for Amazon RedShift Wire Protocol',
#  'MicroStrategy ODBC Driver for Apache Spark SQL',
#  'MicroStrategy Google BigQuery ODBC Driver',
#  'MicroStrategy Impala ODBC Driver',
#  'MicroStrategy Drill ODBC Driver',
#  'MicroStrategy Hive ODBC Driver',
#  'MicroStrategy Cassandra ODBC Driver',
#  'SQL Anywhere 17',
#  'UltraLite 17']

# %%
conn = pyodbc.connect(  db_Driver:'{MySQL ODBC 5.1 Driver}',
                        dbPort: 2631,
                        dbHostName:'p-dbms-db-2',
                        dbCatalogName: 'DWHBIL',
                        dbType: 'Sybase',
                        database='det-dmbs-db',
                        uid='svi02', 
                        pwd='h8JqdsoieV')
print("SUCCESS")
# Out:
#   File "<ipython-input-14-40aca307abb7>", line 1
#     conn = pyodbc.connect(  db_Driver:'{MySQL ODBC 5.1 Driver}',
#                                      ^
# SyntaxError: invalid syntax

# %%
import pyodbc

### Connection to database
conn=pyodbc.connect(DSN="p-dbms-db-2", port=2631, uid='svi02', pwd='h8JqdsoieV') 
# Create cursor associated with connection
cursor=conn.cursor()
### Execute sql
##try:
cursor.execute("SELECT * FROM DWHBIL.V_LKP_HOTEL LIMIT 100")
##except pyodbc.Error, err:
##print err
rows=cursor.fetchall()
#print(rows)

### Close and delet cursor
cursor.close()
del cursor
# Close connection
conn.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-15-6cf7947f77a8> in <module>()
#       2
#       3 ### Connection to database
# ----> 4 conn=pyodbc.connect(DSN="p-dbms-db-2", port=2631, uid='svi02', pwd='h8JqdsoieV')
#       5 # Create cursor associated with connection
#       6 cursor=conn.cursor()
#
# InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect)')

# %%
cursor.execute('SELECT * FROM DWHBIL.V_LKP_HOTEL LIMIT 100')
row = cursor.fetchone()
while row:
    print(row)
    row = cursor.fetchone()
conn.close()

# %%
# Database connection
import sqlalchemy as db
import configparser

#Location of the ini file
config = configparser.ConfigParser()
config.read('C:\\Users\\svi02\\.spyder-py3\\SybaseConnect.ini')
# Out:
# ['C:\\Users\\svi02\\.spyder-py3\\SybaseConnect.ini']

# %%
engine = db.create_engine('sybase+pyodbc://lpr04:78Iychv0K6@p-dbms-db-2:2631/ideas', echo=False)
connection = engine.connect()
print("Success")
# Out:
# C:\Anaconda\lib\site-packages\sqlalchemy\connectors\pyodbc.py:79: SAWarning: No driver name specified; this is expected by PyODBC when using DSN-less connections
#   "No driver name specified; "
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in unique_connection(self)
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     781         if not fairy:
# --> 782             fairy = _ConnectionRecord.checkout(pool)
#     783
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1185                 with util.safe_reraise():
# -> 1186                     self._dec_overflow()
#    1187         else:
#
# C:\Anaconda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# C:\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1182             try:
# -> 1183                 return self._create_connection()
#    1184             except:
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     666             self.starttime = time.time()
# --> 667             connection = pool._invoke_creator(self)
#     668             pool.logger.debug("Created new connection %r", connection)
#
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#
# InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect)')
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-19-f0adb67309e0> in <module>()
#       1 engine = db.create_engine('sybase+pyodbc://lpr04:78Iychv0K6@p-dbms-db-2:2631/ideas', echo=False)
# ----> 2 connection = engine.connect()
#       3 print("Success")
#
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in connect(self, **kwargs)
#    2100         """
#    2101
# -> 2102         return self._connection_cls(self, **kwargs)
#    2103
#    2104     def contextual_connect(self, close_with_result=False, **kwargs):
#
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      88         else:
#      89             self.__connection = connection \
# ---> 90                 if connection is not None else engine.raw_connection()
#      91             self.__transaction = None
#      92             self.__savepoint_seq = 0
#
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    2186         """
#    2187         return self._wrap_pool_connect(
# -> 2188             self.pool.unique_connection, _connection)
#    2189
#    2190
#
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# C:\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# C:\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in unique_connection(self)
#     343
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#     347     def _create_connection(self):
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     780     def _checkout(cls, pool, threadconns=None, fairy=None):
#     781         if not fairy:
# --> 782             fairy = _ConnectionRecord.checkout(pool)
#     783
#     784             fairy._pool = pool
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1184             except:
#    1185                 with util.safe_reraise():
# -> 1186                     self._dec_overflow()
#    1187         else:
#    1188             return self._do_get()
#
# C:\Anaconda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# C:\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1181         if self._inc_overflow():
#    1182             try:
# -> 1183                 return self._create_connection()
#    1184             except:
#    1185                 with util.safe_reraise():
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# C:\Anaconda\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     665         try:
#     666             self.starttime = time.time()
# --> 667             connection = pool._invoke_creator(self)
#     668             pool.logger.debug("Created new connection %r", connection)
#     669             self.connection = connection
#
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     103                         if connection is not None:
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#     107             creator = pop_kwarg('creator', connect)
#
# C:\Anaconda\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     408
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#     412     def create_connect_args(self, url):
#
# InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect)') (Background on this error at: http://sqlalche.me/e/rvf5)
