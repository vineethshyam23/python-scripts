# %%
import pyexasol
import configparser
import pandas as pd

#Location of the ini file
config = configparser.ConfigParser()
config.read('C:\\Users\\svi02\\.spyder-py3\\ExasolPROD.ini')

dsn=config['exasolPROD']['dsn']
user=config['exasolPROD']['user']
pwd=config['exasolPROD']['pwd']
schema=config['exasolPROD']['schema']
# Exasol connection
connect = pyexasol.connect(dsn=dsn, user=user, password=pwd, schema=schema)

# %%
exasol_df = connect.export_to_pandas(""" SELECT
        T.RFP_HOTEL_ID,
        D.MARKET_PLACE_CONTRACT_TYPE_NAME,
        MPHC.MP_HOTEL_CONTRACT_STATUS_NAME,
        TO_DATE(CURRENT_TIMESTAMP)                                         AS PFX_TIMESTAMP,
        EMP.CONTRACT_PERIOD_END,
        EMP.CONTRACT_PERIOD_START
    FROM (SELECT HOTEL_ID AS RFP_HOTEL_ID FROM DWHBIL.LKP_HOTEL) T
    JOIN DWHBIL.LKP_ERFP_MARKET_PLACE EMP ON EMP.HOTEL_ID = T.RFP_HOTEL_ID
    JOIN DWHBIL.LKP_MARKET_PLACE_CONTRACT_TYPE D  ON  EMP.MARKET_PLACE_CONTRACT_TYPE_ID  = D.MARKET_PLACE_CONTRACT_TYPE_ID
    LEFT JOIN  DWHBIL.LKP_MP_HOTEL_CONTRACT_STATUS MPHC ON MPHC.MP_HOTEL_CONTRACT_STATUS_ID = EMP.MP_HOTEL_CONTRACT_STATUS_ID
    """)
exasol_df.head()
# Out:
#    RFP_HOTEL_ID MARKET_PLACE_CONTRACT_TYPE_NAME MP_HOTEL_CONTRACT_STATUS_NAME  \
# 0        657693                            None                       Invited
# 1        945833                            None                       Invited
# 2         53998                            None                       Invited
# 3        409087                            None                       Invited
# 4        961899                            None                     Solicited
#
#   PFX_TIMESTAMP CONTRACT_PERIOD_END CONTRACT_PERIOD_START
# 0    2021-03-22                 NaN                   NaN
# 1    2021-03-22                 NaN                   NaN
# 2    2021-03-22                 NaN                   NaN
# 3    2021-03-22                 NaN                   NaN
# 4    2021-03-22                 NaN                   NaN

# %%
excel_df = pd.read_excel (r'O:\DE\Cologne\HS\Sourcing_Solutions\Special_Folder\Corporate_Sourcing\Sourcing Intelligence\06_Products\Reporting\Sourcing_E2E_RAW_DATA\Sourcing_Report_2021-03-22 09.04.xlsx', sheet_name='MP_Hotels')
excel_df.head()
# Out:
#    HOTEL_ID                      HOTEL_NAME  HOTEL_CHAIN_ID  \
# 0         1                    Savoy Berlin           237.0
# 1         2  Berlin Plaza Am Kurfürstendamm            -1.0
# 2         3               Wyndham Excelsior            -1.0
# 3         9     Hotel Birke, Ringhotel Kiel            63.0
# 4        10                 relexa Bellevue           100.0
#
#      HOTEL_CHAIN_NAME OFFICE_NAME              SALES_AREA HOTEL_WORLD_REGION  \
# 0         WorldHotels  HS Cologne  Germany Berlin Dresden             Europe
# 1          individual  HS Cologne  Germany Berlin Dresden             Europe
# 2          individual  HS Cologne  Germany Berlin Dresden             Europe
# 3     Ringhotels e.V.  HS Cologne         Germany Hamburg             Europe
# 4  relexa hotels GmbH  HS Cologne         Germany Hamburg             Europe
#
#   CHAIN_CLUSTER  HOTEL_BRAND_ID    HOTEL_BRAND_NAME  ...  IB_ACCEPTANCE_QUOTE  \
# 0      Regional           237.0         WorldHotels  ...                  NaN
# 1    Individual            -1.0                n.a.  ...                  NaN
# 2    Individual            -1.0                n.a.  ...                  NaN
# 3         Local            63.0     Ringhotels e.V.  ...                  NaN
# 4         Local           100.0  relexa hotels GmbH  ...                  NaN
#
#   IB_AVERAGE_OFFER_RATE_EURO IB_AVERAGE_TARGET_RATE_EURO  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    IB_AVERAGE_OFFER_RATE_VS_IB_AVG_TARGET_RATE  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   IB_AVERAGE_OFFER_RATE_VS_SMART_BID  IB_TOTAL_AVERAGE_OFFER_RATE_LRA_SHARE  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
#
#    IB_TOTAL_AVERAGE_OFFER_BREAKFAST_INCL_SHARE  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    IB_AVERAGE_OFFER_RATE_EURO_ACCEPTED  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   IB_AVERAGE_ACCEPTED_OFFER_RATE_LRA_SHARE  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   IB_AVERAGE_ACCEPTED_OFFER_RATE_BREAKFAST_INCL_SHARE
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 84 columns]

# %%
# exasol_df.set_index('RFP_HOTEL_ID')
# excel_df.set_index('HOTEL_ID')
exasol_df.reset_index()
excel_df.reset_index()
# Out:
#        index  HOTEL_ID                      HOTEL_NAME  HOTEL_CHAIN_ID  \
# 0          0         1                    Savoy Berlin           237.0
# 1          1         2  Berlin Plaza Am Kurfürstendamm            -1.0
# 2          2         3               Wyndham Excelsior            -1.0
# 3          3         9     Hotel Birke, Ringhotel Kiel            63.0
# 4          4        10                 relexa Bellevue           100.0
# ...      ...       ...                             ...             ...
# 29263  29263   1074742                             NaN             NaN
# 29264  29264   3654448                             NaN             NaN
# 29265  29265   8775680                             NaN             NaN
# 29266  29266  10110115                             NaN             NaN
# 29267  29267  10185508                             NaN             NaN
#
#          HOTEL_CHAIN_NAME OFFICE_NAME              SALES_AREA  \
# 0             WorldHotels  HS Cologne  Germany Berlin Dresden
# 1              individual  HS Cologne  Germany Berlin Dresden
# 2              individual  HS Cologne  Germany Berlin Dresden
# 3         Ringhotels e.V.  HS Cologne         Germany Hamburg
# 4      relexa hotels GmbH  HS Cologne         Germany Hamburg
# ...                   ...         ...                     ...
# 29263                 NaN         NaN                     NaN
# 29264                 NaN         NaN                     NaN
# 29265                 NaN         NaN                     NaN
# 29266                 NaN         NaN                     NaN
# 29267                 NaN         NaN                     NaN
#
#       HOTEL_WORLD_REGION CHAIN_CLUSTER  HOTEL_BRAND_ID  ...  \
# 0                 Europe      Regional           237.0  ...
# 1                 Europe    Individual            -1.0  ...
# 2                 Europe    Individual            -1.0  ...
# 3                 Europe         Local            63.0  ...
# 4                 Europe         Local           100.0  ...
# ...                  ...           ...             ...  ...
# 29263                NaN           NaN             NaN  ...
# 29264                NaN           NaN             NaN  ...
# 29265                NaN           NaN             NaN  ...
# 29266                NaN           NaN             NaN  ...
# 29267                NaN           NaN             NaN  ...
#
#       IB_ACCEPTANCE_QUOTE  IB_AVERAGE_OFFER_RATE_EURO  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
# ...                   ...                         ...
# 29263                 NaN                         NaN
# 29264                 NaN                         NaN
# 29265                 NaN                         NaN
# 29266                 NaN                         NaN
# 29267                 NaN                         NaN
#
#       IB_AVERAGE_TARGET_RATE_EURO IB_AVERAGE_OFFER_RATE_VS_IB_AVG_TARGET_RATE  \
# 0                             NaN                                         NaN
# 1                             NaN                                         NaN
# 2                             NaN                                         NaN
# 3                             NaN                                         NaN
# 4                             NaN                                         NaN
# ...                           ...                                         ...
# 29263                         NaN                                         NaN
# 29264                         NaN                                         NaN
# 29265                         NaN                                         NaN
# 29266                         NaN                                         NaN
# 29267                         NaN                                         NaN
#
#        IB_AVERAGE_OFFER_RATE_VS_SMART_BID  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 29263                                 NaN
# 29264                                 NaN
# 29265                                 NaN
# 29266                                 NaN
# 29267                                 NaN
#
#       IB_TOTAL_AVERAGE_OFFER_RATE_LRA_SHARE  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 29263                                   NaN
# 29264                                   NaN
# 29265                                   NaN
# 29266                                   NaN
# 29267                                   NaN
#
#        IB_TOTAL_AVERAGE_OFFER_BREAKFAST_INCL_SHARE  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 29263                                          NaN
# 29264                                          NaN
# 29265                                          NaN
# 29266                                          NaN
# 29267                                          NaN
#
#        IB_AVERAGE_OFFER_RATE_EURO_ACCEPTED  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 29263                                  NaN
# 29264                                  NaN
# 29265                                  NaN
# 29266                                  NaN
# 29267                                  NaN
#
#        IB_AVERAGE_ACCEPTED_OFFER_RATE_LRA_SHARE  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 29263                                       NaN
# 29264                                       NaN
# 29265                                       NaN
# 29266                                       NaN
# 29267                                       NaN
#
#       IB_AVERAGE_ACCEPTED_OFFER_RATE_BREAKFAST_INCL_SHARE
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29263                                                NaN
# 29264                                                NaN
# 29265                                                NaN
# 29266                                                NaN
# 29267                                                NaN
#
# [29268 rows x 85 columns]

# %%
# Identify what values are in excel_df and not in exasol_df
# key_diff = set(excel_df.HOTEL_ID).difference()
where_diff = excel_df.HOTEL_ID.isin(exasol_df.RFP_HOTEL_ID)

# %%
missing_hotels = excel_df.HOTEL_ID[excel_df.HOTEL_ID.isin(exasol_df.RFP_HOTEL_ID) == False]

# %%
missing_hotels.to_excel(r'C:\Users\svi02\Documents\HPO\missing_hotels_mp.xlsx')
