# %%
import pandas as pd
import datetime as dt
import datefinder
import numpy as np
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings(action='once')
import logging, sys
logging.disable(sys.maxsize)
from dateutil.parser import parse
import datetime
import dateparser

# %%
import re
Queryfile = open("C:\\Users\\svi02\\Documents\\cc\\PFX_HOTEL_BASELINE_RATES.sql", "r") 
Queryfile  = Queryfile.read()

Queryfile  = Queryfile.upper()

print(Queryfile)
word_list = Queryfile.split()

file = open("C:\\Users\\svi02\\Documents\\Python Scripts\\Rule.txt", "r") 
wordDic = {}
for line in file:
    x = line.split("|")
    a = x[0]
    b= x[1]
    wordDic[a] = b

text = Queryfile
def replace_all(text, dic):
    for i, j in dic.items():
        #print(text)
        #print("--------")
        #text = text.replace(i, j)
        #for word in word_list:
        redata = re.compile(re.escape(i), re.IGNORECASE)
        #print(i)
        #print("--------")
        new_text = redata.sub(j, text)
        #print(j)
        #print("--------")
        #print(new_text)
        print("---------" +  new_text)         
    return new_text

#print(replace_all(text, wordDic))


def word_replace(text, replace_dict):
    rc = re.compile(r"[A-Za-z_]\w*")
    def translate(match):
        word = match.group(0)
        
        return replace_dict.get(word, word)
    print( text)
    return rc.sub(translate, text)

def multiwordReplace(text, wordDic):
    rc = re.compile('|'.join(map(re.escape, wordDic)))
    def translate(match):
        return wordDic[match.group(0)]
    return rc.sub(translate, text)
# Out:
# INSERT INTO  DWHPFX.PFX_HOTEL_BASELINE_RATES
# SELECT DISTINCT
#     RFP_HOTEL_ID,
#     RFP_HOTEL_FLAG,
#     RFP_HOTEL_CURRENCY,
#     RFP_HOTEL_BASELINE_RATE_TYPE,
#     RFP_HOTEL_EXCHANGE_DATE,
#     RFP_HOTEL_EXCHANGE_RATE,
#     CASE WHEN RFP_HOTEL_BASELINE_RATE_ORIGINAL = 0 THEN NULL ELSE RFP_HOTEL_BASELINE_RATE_ORIGINAL END AS RFP_HOTEL_BASELINE_RATE_ORIGINAL,
#     CASE WHEN RFP_HOTEL_BASELINE_RATE_EUR = 0 THEN NULL ELSE RFP_HOTEL_BASELINE_RATE_EUR END AS RFP_HOTEL_BASELINE_RATE_EUR,
#     RFP_HOTEL_BASELINE_RATE_SOURCE,
#     CASE WHEN (ROUND(COALESCE(LRA_INCL, LRA_INCL_FROM_NLRA),2) <=0) THEN NULL ELSE ROUND(COALESCE(LRA_INCL, LRA_INCL_FROM_NLRA),2) END AS AMOUNT_RATE_EUR_LRA_INCL,
#     CASE WHEN (ROUND(COALESCE(LRA_EXCL, LRA_EXCL_FROM_NLRA),2) <=0) THEN NULL ELSE ROUND(COALESCE(LRA_EXCL, LRA_EXCL_FROM_NLRA),2) END AS AMOUNT_RATE_EUR_LRA_EXCL,
#     CASE WHEN (ROUND(COALESCE(NLRA_INCL, NLRA_INCL_FROM_LRA),2) <= 0) THEN NULL ELSE ROUND(COALESCE(NLRA_INCL, NLRA_INCL_FROM_LRA),2) END AS AMOUNT_RATE_EUR_NLRA_INCL,
#     CASE WHEN (ROUND(COALESCE(NLRA_EXCL, NLRA_EXCL_FROM_LRA),2) <= 0) THEN NULL ELSE ROUND(COALESCE(NLRA_EXCL, NLRA_EXCL_FROM_LRA),2) END AS AMOUNT_RATE_EUR_NLRA_EXCL
# FROM (
# SELECT
#     RFP_HTL.HOTEL_ID_VALUE                          AS RFP_HOTEL_ID,
#     CASE
#         WHEN (RFP_HTL.IS_SOURCING_CONTRACT_HOTEL_OF_LAST_YEAR = 1) THEN ('CH')
#         WHEN (RFP_HTL.CLIENT_REQUESTED = 1) THEN ('LD')
#         ELSE ('AH')
#     END                                             AS RFP_HOTEL_FLAG,
#     COALESCE(RFP_BL.BASELINE_CURRENCY,'EUR')        AS RFP_HOTEL_CURRENCY,
#     CASE
# 		WHEN (RFP_BL.BASELINE_RATE IS NULL AND RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT IS NULL) THEN (NULL)
#         WHEN (RFP_BL.RATE_TYPE_ IS NOT NULL) THEN (RFP_BL.RATE_TYPE_)
#         ELSE ('NLRA_INCL')
#     END                                             					    AS RFP_HOTEL_BASELINE_RATE_TYPE,
#     RFP_CURD.RFP_CURRENCY_DATE                      AS RFP_HOTEL_EXCHANGE_DATE,
#     COALESCE(EXCH.CURRENCY_EXCHANGE_RATE,EXCH_R.CURRENCY_EXCHANGE_RATE,1.00) AS RFP_HOTEL_EXCHANGE_RATE,
#     ROUND(CASE
#         WHEN (RFP_BL.BASELINE_RATE IS NULL)
#         THEN (CAST(RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT AS DECIMAL(15,6)))
#         ELSE (CAST(RFP_BL.BASELINE_RATE AS DECIMAL(15,6)))
#     END,3)                                           AS RFP_HOTEL_BASELINE_RATE_ORIGINAL,
#     ROUND(CASE
#         WHEN (RFP_BL.BASELINE_RATE IS NULL)
#         THEN (CAST(RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT AS DECIMAL(15,6)))
#         ELSE (CAST(RFP_BL.BASELINE_RATE AS DECIMAL(15,6))/ COALESCE(EXCH.CURRENCY_EXCHANGE_RATE,EXCH_R.CURRENCY_EXCHANGE_RATE,1))
#     END,2)                                           AS RFP_HOTEL_BASELINE_RATE_EUR,
# CASE
#         WHEN RFP_BL.BASELINE_RATE IS NOT NULL
#         THEN 'CONTRACTED RATE'
#         WHEN RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT IS NOT NULL
#         THEN 'AVG BOOKED RATE'
#         ELSE 'NO BASELINE RATE'
#     END AS RFP_HOTEL_BASELINE_RATE_SOURCE,
#     COALESCE(BH.AMOUNT_BREAKFAST_EUR,10) AS AMOUNT_BREAKFAST_EUR
#     ,CASE
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL')
# 		THEN RFP_HOTEL_BASELINE_RATE_EUR
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL')
# 		THEN RFP_HOTEL_BASELINE_RATE_EUR + AMOUNT_BREAKFAST_EUR
# 		ELSE NULL
# 	END         AS LRA_INCL
# 	,CASE
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL')
# 		THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) * 1.10 + AMOUNT_BREAKFAST_EUR
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL')
# 		THEN (RFP_HOTEL_BASELINE_RATE_EUR) * 1.10 + AMOUNT_BREAKFAST_EUR
# 		ELSE NULL
# 	END         AS LRA_INCL_FROM_NLRA
# 	,CASE
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL')
# 		THEN RFP_HOTEL_BASELINE_RATE_EUR
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL')
# 		THEN RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR
# 		ELSE NULL
# 	END         AS LRA_EXCL
# 	,CASE
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL')
# 		THEN (RFP_HOTEL_BASELINE_RATE_EUR) * 1.10
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL')
# 		THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) * 1.10
# 		ELSE NULL
# 	END         AS LRA_EXCL_FROM_NLRA
# 	,CASE
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL')
# 		THEN RFP_HOTEL_BASELINE_RATE_EUR
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL')
# 		THEN RFP_HOTEL_BASELINE_RATE_EUR + AMOUNT_BREAKFAST_EUR
# 		ELSE NULL
# 	END         AS NLRA_INCL
# 	,CASE
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL')
# 		THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) / 1.10 + AMOUNT_BREAKFAST_EUR
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL')
# 		THEN (RFP_HOTEL_BASELINE_RATE_EUR) / 1.10 + AMOUNT_BREAKFAST_EUR
# 		ELSE NULL
# 	END         AS NLRA_INCL_FROM_LRA
# 	,CASE
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL')
# 		THEN RFP_HOTEL_BASELINE_RATE_EUR
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL')
# 		THEN RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR
# 		ELSE NULL
# 	END         AS NLRA_EXCL
# 	,CASE
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL')
# 		THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) / 1.10
# 		WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL')
# 		THEN (RFP_HOTEL_BASELINE_RATE_EUR) / 1.10
# 		ELSE NULL
# 	END         AS NLRA_EXCL_FROM_LRA
# FROM  DWHPFX.ERFP_HOTEL_FOR_RFP RFP_HTL
# INNER JOIN  DWHPFX.ERFP_RFP_PROCESS RFP_PROC ON RFP_PROC.RFP_ID = RFP_HTL.OR_RFP_VALUE
# LEFT JOIN  DWHPFX.ERFP_BASELINE_RATES RFP_BL ON RFP_BL.HOTEL_ID_VALUE = RFP_HTL.HOTEL_ID_VALUE
# INNER JOIN  DWHPFX.PFX_CURRENCY_DATE RFP_CURD ON RFP_CURD.RFP_ID = RFP_HTL.OR_RFP_VALUE
# LEFT JOIN DWHBIL.LKP_CURRENCY_EXCHANGE_RATE_HIST EXCH
#     ON EXCH.CURRENCY_EXCHANGE_RATE_DATE = RFP_CURD.RFP_CURRENCY_DATE AND EXCH.CURRENCY_ISO = RFP_BL.BASELINE_CURRENCY
# LEFT JOIN DWHBIL.LKP_CURRENCY_EXCHANGE_RATE EXCH_R
#     ON EXCH_R.CURRENCY_ISO = RFP_BL.BASELINE_CURRENCY
# LEFT JOIN DWHBIL.LKP_BREAKFAST_HOTEL_LEVEL BH ON BH.HOTEL_ID = RFP_HTL.HOTEL_ID_VALUE
# ) A
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\svi02\\Documents\\cc\\PFX_HOTEL_BASELINE_RATES.sql' mode='r' encoding='cp1252'>
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:10: ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\svi02\\Documents\\Python Scripts\\Rule.txt' mode='r' encoding='cp1252'>
#   # Remove the CWD from sys.path while we load stuff.

# %%
#normal Replacement
Queryfile = multiwordReplace(Queryfile,wordDic)

normalreplacequery = multiwordReplace(Queryfile,wordDic)
s=""
s = normalreplacequery
underscorequery =""
wordlist = s.split()
for word in range(len(wordlist)):
    if "._" in wordlist[word]:
        strval = wordlist[word]
        wordlist[word] = strval[0 : strval.index(".")+1] + "\"" + strval[strval.index(".")+1 : len(strval)]  + "\""
    else:
        strval = wordlist[word]
        if(strval[0] =="_"):
            wordlist[word] = "\"" + strval  + "\""
            
        #underscoreword=  s[s.index("._"):s.index("._")+re.search("\W+", s[s.index("._"):len(s)]).start()]
        #s = s.replace(underscoreword,"\"" + underscoreword + "\"") 
#leading underscore replacement
for word in wordlist:
    underscorequery = underscorequery + " " + word   
print(underscorequery)

#underscorequery = s
# Out:
#  INSERT INTO DWHPFX.PFX_HOTEL_BASELINE_RATES SELECT DISTINCT RFP_HOTEL_ID, RFP_HOTEL_FLAG, RFP_HOTEL_CURRENCY, RFP_HOTEL_BASELINE_RATE_TYPE, RFP_HOTEL_EXCHANGE_DATE, RFP_HOTEL_EXCHANGE_RATE, CASE WHEN RFP_HOTEL_BASELINE_RATE_ORIGINAL = 0 THEN NULL ELSE RFP_HOTEL_BASELINE_RATE_ORIGINAL END AS RFP_HOTEL_BASELINE_RATE_ORIGINAL, CASE WHEN RFP_HOTEL_BASELINE_RATE_EUR = 0 THEN NULL ELSE RFP_HOTEL_BASELINE_RATE_EUR END AS RFP_HOTEL_BASELINE_RATE_EUR, RFP_HOTEL_BASELINE_RATE_SOURCE, CASE WHEN (ROUND(COALESCE(LRA_INCL, LRA_INCL_FROM_NLRA),2) <=0) THEN NULL ELSE ROUND(COALESCE(LRA_INCL, LRA_INCL_FROM_NLRA),2) END AS AMOUNT_RATE_EUR_LRA_INCL, CASE WHEN (ROUND(COALESCE(LRA_EXCL, LRA_EXCL_FROM_NLRA),2) <=0) THEN NULL ELSE ROUND(COALESCE(LRA_EXCL, LRA_EXCL_FROM_NLRA),2) END AS AMOUNT_RATE_EUR_LRA_EXCL, CASE WHEN (ROUND(COALESCE(NLRA_INCL, NLRA_INCL_FROM_LRA),2) <= 0) THEN NULL ELSE ROUND(COALESCE(NLRA_INCL, NLRA_INCL_FROM_LRA),2) END AS AMOUNT_RATE_EUR_NLRA_INCL, CASE WHEN (ROUND(COALESCE(NLRA_EXCL, NLRA_EXCL_FROM_LRA),2) <= 0) THEN NULL ELSE ROUND(COALESCE(NLRA_EXCL, NLRA_EXCL_FROM_LRA),2) END AS AMOUNT_RATE_EUR_NLRA_EXCL FROM ( SELECT RFP_HTL.HOTEL_ID_VALUE AS RFP_HOTEL_ID, CASE WHEN (RFP_HTL.IS_SOURCING_CONTRACT_HOTEL_OF_LAST_YEAR = 1) THEN ('CH') WHEN (RFP_HTL.CLIENT_REQUESTED = 1) THEN ('LD') ELSE ('AH') END AS RFP_HOTEL_FLAG, COALESCE(RFP_BL.BASELINE_CURRENCY,'EUR') AS RFP_HOTEL_CURRENCY, CASE WHEN (RFP_BL.BASELINE_RATE IS NULL AND RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT IS NULL) THEN (NULL) WHEN (RFP_BL.RATE_TYPE_ IS NOT NULL) THEN (RFP_BL.RATE_TYPE_) ELSE ('NLRA_INCL') END AS RFP_HOTEL_BASELINE_RATE_TYPE, RFP_CURD.RFP_CURRENCY_DATE AS RFP_HOTEL_EXCHANGE_DATE, COALESCE(EXCH.CURRENCY_EXCHANGE_RATE,EXCH_R.CURRENCY_EXCHANGE_RATE,1.00) AS RFP_HOTEL_EXCHANGE_RATE, ROUND(CASE WHEN (RFP_BL.BASELINE_RATE IS NULL) THEN (CAST(RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT AS DECIMAL(15,6))) ELSE (CAST(RFP_BL.BASELINE_RATE AS DECIMAL(15,6))) END,3) AS RFP_HOTEL_BASELINE_RATE_ORIGINAL, ROUND(CASE WHEN (RFP_BL.BASELINE_RATE IS NULL) THEN (CAST(RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT AS DECIMAL(15,6))) ELSE (CAST(RFP_BL.BASELINE_RATE AS DECIMAL(15,6))/ COALESCE(EXCH.CURRENCY_EXCHANGE_RATE,EXCH_R.CURRENCY_EXCHANGE_RATE,1)) END,2) AS RFP_HOTEL_BASELINE_RATE_EUR, CASE WHEN RFP_BL.BASELINE_RATE IS NOT NULL THEN 'CONTRACTED RATE' WHEN RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT IS NOT NULL THEN 'AVG BOOKED RATE' ELSE 'NO BASELINE RATE' END AS RFP_HOTEL_BASELINE_RATE_SOURCE, COALESCE(BH.AMOUNT_BREAKFAST_EUR,10) AS AMOUNT_BREAKFAST_EUR ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL') THEN RFP_HOTEL_BASELINE_RATE_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL') THEN RFP_HOTEL_BASELINE_RATE_EUR + AMOUNT_BREAKFAST_EUR ELSE NULL END AS LRA_INCL ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) * 1.10 + AMOUNT_BREAKFAST_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR) * 1.10 + AMOUNT_BREAKFAST_EUR ELSE NULL END AS LRA_INCL_FROM_NLRA ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL') THEN RFP_HOTEL_BASELINE_RATE_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL') THEN RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR ELSE NULL END AS LRA_EXCL ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR) * 1.10 WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) * 1.10 ELSE NULL END AS LRA_EXCL_FROM_NLRA ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL') THEN RFP_HOTEL_BASELINE_RATE_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL') THEN RFP_HOTEL_BASELINE_RATE_EUR + AMOUNT_BREAKFAST_EUR ELSE NULL END AS NLRA_INCL ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) / 1.10 + AMOUNT_BREAKFAST_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR) / 1.10 + AMOUNT_BREAKFAST_EUR ELSE NULL END AS ...

# %%
#Queryfile = tempquery

Queryfile = multiwordReplace(underscorequery,wordDic)
s = Queryfile
wordlist = s.split()
    
matches1 = datefinder.find_dates(s)
matches2 = datefinder.find_dates(str(s),True,False)
matches = list(datefinder.find_dates(s))    

ff=""
matchflag = 0
for match in matches2:     
    
    matchflag = 1
   
    wl = (str(match).split(","))
    wl[5] = wl[5].lstrip(" ")
    wl[5] = wl[5].rstrip(" ")
    if(len(wl[5]) >8):
        
        x = match
        wl = (str(match).split(","))
        newx = wl[0].lstrip("(datetime.datetime(") + "," + wl[1]+"," + wl[2]

        if(int(wl[0].lstrip("(datetime.datetime("))>2000):
            x = datetime.datetime(int(wl[0].lstrip("(datetime.datetime(")) , int(wl[1]), int(wl[2]))
            datefi = str(x).split(" ")[0]
            
            
            actualdate = wl[5].lstrip("\" '")
            actualdate = actualdate.rstrip("')")
            field2 = s[:s.index(actualdate)].split(" ")[-3] + " " +   s[:s.index(actualdate)].split(" ")[-2]
            
            if (s[:s.index(actualdate)].split(" ")[-2] != "AND"):
                s = s.replace(field2, "to_date(" + field2.split(" ")[0] +  ",\'YYYY-MM-DD\')" + " " + field2.split(" ")[1])

                s = s.replace(actualdate, datefi)

            s = s.replace(actualdate, datefi)
            s = s.replace(actualdate, datefi)

      
            
            
if matchflag ==1 :     
    datequery = s
else:
    datequery = s

print(datequery)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-634f3ac49eb3> in <module>()
#      32             actualdate = wl[5].lstrip("\" '")
#      33             actualdate = actualdate.rstrip("')")
# ---> 34             field2 = s[:s.index(actualdate)].split(" ")[-3] + " " +   s[:s.index(actualdate)].split(" ")[-2]
#      35
#      36             if (s[:s.index(actualdate)].split(" ")[-2] != "AND"):
#
# ValueError: substring not found

# %%
#normal Replacement
Queryfile = multiwordReplace(Queryfile,wordDic)

normalreplacequery = multiwordReplace(Queryfile,wordDic)
s=""
s = normalreplacequery
underscorequery =""
wordlist = s.split()
for word in range(len(wordlist)):
    if "._" in wordlist[word]:
        strval = wordlist[word]
        wordlist[word] = strval[0 : strval.index(".")+1] + "\"" + strval[strval.index(".")+1 : len(strval)]  + "\""
    else:
        strval = wordlist[word]
        if(strval[0] =="_"):
            wordlist[word] = "\"" + strval  + "\""
            
        #underscoreword=  s[s.index("._"):s.index("._")+re.search("\W+", s[s.index("._"):len(s)]).start()]
        #s = s.replace(underscoreword,"\"" + underscoreword + "\"") 
#leading underscore replacement
for word in wordlist:
    underscorequery = underscorequery + " " + word   
print(underscorequery)

#underscorequery = s
# Out:
#  INSERT INTO DWHPFX.PFX_HOTEL_BASELINE_RATES SELECT DISTINCT RFP_HOTEL_ID, RFP_HOTEL_FLAG, RFP_HOTEL_CURRENCY, RFP_HOTEL_BASELINE_RATE_TYPE, RFP_HOTEL_EXCHANGE_DATE, RFP_HOTEL_EXCHANGE_RATE, CASE WHEN RFP_HOTEL_BASELINE_RATE_ORIGINAL = 0 THEN NULL ELSE RFP_HOTEL_BASELINE_RATE_ORIGINAL END AS RFP_HOTEL_BASELINE_RATE_ORIGINAL, CASE WHEN RFP_HOTEL_BASELINE_RATE_EUR = 0 THEN NULL ELSE RFP_HOTEL_BASELINE_RATE_EUR END AS RFP_HOTEL_BASELINE_RATE_EUR, RFP_HOTEL_BASELINE_RATE_SOURCE, CASE WHEN (ROUND(COALESCE(LRA_INCL, LRA_INCL_FROM_NLRA),2) <=0) THEN NULL ELSE ROUND(COALESCE(LRA_INCL, LRA_INCL_FROM_NLRA),2) END AS AMOUNT_RATE_EUR_LRA_INCL, CASE WHEN (ROUND(COALESCE(LRA_EXCL, LRA_EXCL_FROM_NLRA),2) <=0) THEN NULL ELSE ROUND(COALESCE(LRA_EXCL, LRA_EXCL_FROM_NLRA),2) END AS AMOUNT_RATE_EUR_LRA_EXCL, CASE WHEN (ROUND(COALESCE(NLRA_INCL, NLRA_INCL_FROM_LRA),2) <= 0) THEN NULL ELSE ROUND(COALESCE(NLRA_INCL, NLRA_INCL_FROM_LRA),2) END AS AMOUNT_RATE_EUR_NLRA_INCL, CASE WHEN (ROUND(COALESCE(NLRA_EXCL, NLRA_EXCL_FROM_LRA),2) <= 0) THEN NULL ELSE ROUND(COALESCE(NLRA_EXCL, NLRA_EXCL_FROM_LRA),2) END AS AMOUNT_RATE_EUR_NLRA_EXCL FROM ( SELECT RFP_HTL.HOTEL_ID_VALUE AS RFP_HOTEL_ID, CASE WHEN (RFP_HTL.IS_SOURCING_CONTRACT_HOTEL_OF_LAST_YEAR = 1) THEN ('CH') WHEN (RFP_HTL.CLIENT_REQUESTED = 1) THEN ('LD') ELSE ('AH') END AS RFP_HOTEL_FLAG, COALESCE(RFP_BL.BASELINE_CURRENCY,'EUR') AS RFP_HOTEL_CURRENCY, CASE WHEN (RFP_BL.BASELINE_RATE IS NULL AND RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT IS NULL) THEN (NULL) WHEN (RFP_BL.RATE_TYPE_ IS NOT NULL) THEN (RFP_BL.RATE_TYPE_) ELSE ('NLRA_INCL') END AS RFP_HOTEL_BASELINE_RATE_TYPE, RFP_CURD.RFP_CURRENCY_DATE AS RFP_HOTEL_EXCHANGE_DATE, COALESCE(EXCH.CURRENCY_EXCHANGE_RATE,EXCH_R.CURRENCY_EXCHANGE_RATE,1.00) AS RFP_HOTEL_EXCHANGE_RATE, ROUND(CASE WHEN (RFP_BL.BASELINE_RATE IS NULL) THEN (CAST(RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT AS DECIMAL(15,6))) ELSE (CAST(RFP_BL.BASELINE_RATE AS DECIMAL(15,6))) END,3) AS RFP_HOTEL_BASELINE_RATE_ORIGINAL, ROUND(CASE WHEN (RFP_BL.BASELINE_RATE IS NULL) THEN (CAST(RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT AS DECIMAL(15,6))) ELSE (CAST(RFP_BL.BASELINE_RATE AS DECIMAL(15,6))/ COALESCE(EXCH.CURRENCY_EXCHANGE_RATE,EXCH_R.CURRENCY_EXCHANGE_RATE,1)) END,2) AS RFP_HOTEL_BASELINE_RATE_EUR, CASE WHEN RFP_BL.BASELINE_RATE IS NOT NULL THEN 'CONTRACTED RATE' WHEN RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT IS NOT NULL THEN 'AVG BOOKED RATE' ELSE 'NO BASELINE RATE' END AS RFP_HOTEL_BASELINE_RATE_SOURCE, COALESCE(BH.AMOUNT_BREAKFAST_EUR,10) AS AMOUNT_BREAKFAST_EUR ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL') THEN RFP_HOTEL_BASELINE_RATE_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL') THEN RFP_HOTEL_BASELINE_RATE_EUR + AMOUNT_BREAKFAST_EUR ELSE NULL END AS LRA_INCL ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) * 1.10 + AMOUNT_BREAKFAST_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR) * 1.10 + AMOUNT_BREAKFAST_EUR ELSE NULL END AS LRA_INCL_FROM_NLRA ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL') THEN RFP_HOTEL_BASELINE_RATE_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL') THEN RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR ELSE NULL END AS LRA_EXCL ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR) * 1.10 WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) * 1.10 ELSE NULL END AS LRA_EXCL_FROM_NLRA ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL') THEN RFP_HOTEL_BASELINE_RATE_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL') THEN RFP_HOTEL_BASELINE_RATE_EUR + AMOUNT_BREAKFAST_EUR ELSE NULL END AS NLRA_INCL ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) / 1.10 + AMOUNT_BREAKFAST_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR) / 1.10 + AMOUNT_BREAKFAST_EUR ELSE NULL END AS ...

# %%
#HAndle Alias  replacement

s = underscorequery
list_of_words = s.split()

match = re.compile(r'AS (\w+)')
aliasword = match.findall(s)



for  i in range(len(aliasword)) :
    
    for j in range(len(list_of_words)):
        if(j<len(list_of_words)-1):
        
            if((aliasword[i] == list_of_words[j]) & (str(list_of_words[j-1]) != str("AS")) & (str(list_of_words[j+1]) != str("AS"))):
                list_of_words[j] = "LOCAL." + aliasword[i]

            j +=1
    
      
    i += 1

aliasquery=""
for word in list_of_words:
    aliasquery = aliasquery + " " + word 
    
print(aliasquery)
# Out:
#  INSERT INTO DWHPFX.PFX_HOTEL_BASELINE_RATES SELECT DISTINCT RFP_HOTEL_ID, RFP_HOTEL_FLAG, RFP_HOTEL_CURRENCY, RFP_HOTEL_BASELINE_RATE_TYPE, RFP_HOTEL_EXCHANGE_DATE, RFP_HOTEL_EXCHANGE_RATE, CASE WHEN LOCAL.RFP_HOTEL_BASELINE_RATE_ORIGINAL = 0 THEN NULL ELSE LOCAL.RFP_HOTEL_BASELINE_RATE_ORIGINAL END AS RFP_HOTEL_BASELINE_RATE_ORIGINAL, CASE WHEN LOCAL.RFP_HOTEL_BASELINE_RATE_EUR = 0 THEN NULL ELSE LOCAL.RFP_HOTEL_BASELINE_RATE_EUR END AS RFP_HOTEL_BASELINE_RATE_EUR, RFP_HOTEL_BASELINE_RATE_SOURCE, CASE WHEN (ROUND(COALESCE(LRA_INCL, LRA_INCL_FROM_NLRA),2) <=0) THEN NULL ELSE ROUND(COALESCE(LRA_INCL, LRA_INCL_FROM_NLRA),2) END AS AMOUNT_RATE_EUR_LRA_INCL, CASE WHEN (ROUND(COALESCE(LRA_EXCL, LRA_EXCL_FROM_NLRA),2) <=0) THEN NULL ELSE ROUND(COALESCE(LRA_EXCL, LRA_EXCL_FROM_NLRA),2) END AS AMOUNT_RATE_EUR_LRA_EXCL, CASE WHEN (ROUND(COALESCE(NLRA_INCL, NLRA_INCL_FROM_LRA),2) <= 0) THEN NULL ELSE ROUND(COALESCE(NLRA_INCL, NLRA_INCL_FROM_LRA),2) END AS AMOUNT_RATE_EUR_NLRA_INCL, CASE WHEN (ROUND(COALESCE(NLRA_EXCL, NLRA_EXCL_FROM_LRA),2) <= 0) THEN NULL ELSE ROUND(COALESCE(NLRA_EXCL, NLRA_EXCL_FROM_LRA),2) END AS AMOUNT_RATE_EUR_NLRA_EXCL FROM ( SELECT RFP_HTL.HOTEL_ID_VALUE AS RFP_HOTEL_ID, CASE WHEN (RFP_HTL.IS_SOURCING_CONTRACT_HOTEL_OF_LAST_YEAR = 1) THEN ('CH') WHEN (RFP_HTL.CLIENT_REQUESTED = 1) THEN ('LD') ELSE ('AH') END AS RFP_HOTEL_FLAG, COALESCE(RFP_BL.BASELINE_CURRENCY,'EUR') AS RFP_HOTEL_CURRENCY, CASE WHEN (RFP_BL.BASELINE_RATE IS NULL AND RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT IS NULL) THEN (NULL) WHEN (RFP_BL.RATE_TYPE_ IS NOT NULL) THEN (RFP_BL.RATE_TYPE_) ELSE ('NLRA_INCL') END AS RFP_HOTEL_BASELINE_RATE_TYPE, RFP_CURD.RFP_CURRENCY_DATE AS RFP_HOTEL_EXCHANGE_DATE, COALESCE(EXCH.CURRENCY_EXCHANGE_RATE,EXCH_R.CURRENCY_EXCHANGE_RATE,1.00) AS RFP_HOTEL_EXCHANGE_RATE, ROUND(CASE WHEN (RFP_BL.BASELINE_RATE IS NULL) THEN (CAST(RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT AS DECIMAL(15,6))) ELSE (CAST(RFP_BL.BASELINE_RATE AS DECIMAL(15,6))) END,3) AS RFP_HOTEL_BASELINE_RATE_ORIGINAL, ROUND(CASE WHEN (RFP_BL.BASELINE_RATE IS NULL) THEN (CAST(RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT AS DECIMAL(15,6))) ELSE (CAST(RFP_BL.BASELINE_RATE AS DECIMAL(15,6))/ COALESCE(EXCH.CURRENCY_EXCHANGE_RATE,EXCH_R.CURRENCY_EXCHANGE_RATE,1)) END,2) AS RFP_HOTEL_BASELINE_RATE_EUR, CASE WHEN RFP_BL.BASELINE_RATE IS NOT NULL THEN 'CONTRACTED RATE' WHEN RFP_HTL.AVERAGE_RATE_IN_EUR_AMOUNT IS NOT NULL THEN 'AVG BOOKED RATE' ELSE 'NO BASELINE RATE' END AS RFP_HOTEL_BASELINE_RATE_SOURCE, COALESCE(BH.AMOUNT_BREAKFAST_EUR,10) AS AMOUNT_BREAKFAST_EUR ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL') THEN LOCAL.RFP_HOTEL_BASELINE_RATE_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL') THEN LOCAL.RFP_HOTEL_BASELINE_RATE_EUR + LOCAL.AMOUNT_BREAKFAST_EUR ELSE NULL END AS LRA_INCL ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) * 1.10 + LOCAL.AMOUNT_BREAKFAST_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR) * 1.10 + LOCAL.AMOUNT_BREAKFAST_EUR ELSE NULL END AS LRA_INCL_FROM_NLRA ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_EXCL') THEN LOCAL.RFP_HOTEL_BASELINE_RATE_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL') THEN LOCAL.RFP_HOTEL_BASELINE_RATE_EUR - LOCAL.AMOUNT_BREAKFAST_EUR ELSE NULL END AS LRA_EXCL ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR) * 1.10 WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) * 1.10 ELSE NULL END AS LRA_EXCL_FROM_NLRA ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_INCL') THEN LOCAL.RFP_HOTEL_BASELINE_RATE_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'NLRA_EXCL') THEN LOCAL.RFP_HOTEL_BASELINE_RATE_EUR + LOCAL.AMOUNT_BREAKFAST_EUR ELSE NULL END AS NLRA_INCL ,CASE WHEN (RFP_HOTEL_BASELINE_RATE_TYPE = 'LRA_INCL') THEN (RFP_HOTEL_BASELINE_RATE_EUR - AMOUNT_BREAKFAST_EUR) / 1.10 + LOCAL.AMOUNT_BREAKFAST_EUR WHEN (RFP_HOTEL_BASELINE_RATE_TYPE ...

# %%
#ADDRESSING TEMP TABLES TO WITH CLAUSE

Queryfile = aliasquery
#Queryfile = aliasquery
newlist = []
INTOFROM = 0
withrepace = {}
substring1 = 'INTO'
substring2 = 'FROM'
queriesnoINTO =""

if(any([substring1 == word for word in Queryfile.split()]) == True):
    if ";" in Queryfile:
        setqueries = Queryfile.split(";")

        for queries in setqueries:
            if "INTO" in queries:
                INTOFROM = 1
                if queries :
                    s = queries

                    hashmy_string = s[(s.index(substring1)+len(substring1)):s.index(substring2)]

                    my_string = s[(s.index(substring1)+len(substring1)):s.index(substring2)]
                    my_string = my_string.strip('\n')
                    my_string = my_string.strip('\t')
                    my_string = my_string.strip(' ')
                    hashmy_string = my_string
                    my_string = my_string.lstrip("#")

                    WITHTABLENAME = my_string

                    s = s.replace(s[(s.index(substring1)):s.index(substring2)] ,"")
                    s  = WITHTABLENAME + " AS (" + s + ")"
                    newlist.append(s)

                    withrepace[hashmy_string] = WITHTABLENAME

            else:
                queriesnoINTO = queriesnoINTO + queries
                #print(queriesnoINTO)
                
if(any([word == "GO" for word in Queryfile.split()]) == True):

        setqueries = Queryfile.split("GO")
        for queries in setqueries:
            if "INTO" in queries:
                INTOFROM = 1
                if queries :
                    s = queries

                    hashmy_string = s[(s.index(substring1)+len(substring1)):s.index(substring2)]

                    my_string = s[(s.index(substring1)+len(substring1)):s.index(substring2)]
                    my_string = my_string.strip('\n')
                    my_string = my_string.strip('\t')
                    my_string = my_string.strip(' ')
                    hashmy_string = my_string
                    my_string = my_string.lstrip("#")

                    WITHTABLENAME = my_string

                    s = s.replace(s[(s.index(substring1)):s.index(substring2)] ,"")
                    s  = WITHTABLENAME + " AS (" + s + ")"
                    newlist.append(s)

                    withrepace[hashmy_string] = WITHTABLENAME
            else:
                queriesnoINTO = queriesnoINTO + queries

if(INTOFROM==1):
    
    Queryready = (',\n'.join(newlist)) 

    Queryready = "WITH " + Queryready + " " + queriesnoINTO

    Queryready = Queryready.rstrip(")")
    Queryfile = multiwordReplace(Queryready, withrepace)


wordlist = Queryfile.split()

#remove the query drop table #temp
for  i in range(len(wordlist)) :
    if(i<len(wordlist)-1):
            if((wordlist[i] == "DROP") & (wordlist[i+1] == "TABLE")):
                wordlist[i] =""
                wordlist[i+1] =""
                wordlist[i+2] =""   
    i += 1
    
tempquery=""
for word in wordlist:
    tempquery = tempquery + " " + word    

print(tempquery)
# Out:
#  WITH ORIGHOTEL AS ( SELECT HOTEL_ID, HOTEL_CITY_ID FROM DWHBIL.V_LKP_HOTEL WHERE LOCAL.HOTEL_ID = MATTHIASISTGEIL ), SIMHOTELS AS ( SELECT SIM.HOTEL_ID , SIM.SIMILAR_HOTEL_ID , SIM.SIMILAR_HOTEL_SIMILARITY , SIM.SIMILAR_HOTEL_DISTANCE_KM , CASE WHEN SIM.SIMILAR_HOTEL_DISTANCE_KM <= 1 AND SIM.SIMILAR_HOTEL_SIMILARITY >= 0.7 THEN DENSE_RANK() OVER (PARTITION BY SIM.HOTEL_ID ORDER BY SIM.SIMILAR_HOTEL_SIMILARITY DESC) ELSE 0 END * 0.000001 AS RANG_1 , CASE WHEN SIM.SIMILAR_HOTEL_DISTANCE_KM <= 3 AND SIM.SIMILAR_HOTEL_DISTANCE_KM > 1 AND SIM.SIMILAR_HOTEL_SIMILARITY >= 0.7 THEN DENSE_RANK() OVER (PARTITION BY SIM.HOTEL_ID ORDER BY SIM.SIMILAR_HOTEL_SIMILARITY DESC) ELSE 0 END *0.0001 AS RANG_2 , CASE WHEN SIM.SIMILAR_HOTEL_DISTANCE_KM <= 1 AND SIM.SIMILAR_HOTEL_SIMILARITY < 0.7 AND SIM.SIMILAR_HOTEL_SIMILARITY >= 0.6 THEN DENSE_RANK() OVER (PARTITION BY SIM.HOTEL_ID ORDER BY SIM.SIMILAR_HOTEL_SIMILARITY DESC) ELSE 0 END*0.01 AS RANG_3 , CASE WHEN SIM.SIMILAR_HOTEL_DISTANCE_KM <= 3 AND SIM.SIMILAR_HOTEL_DISTANCE_KM > 1 AND SIM.SIMILAR_HOTEL_SIMILARITY < 0.7 AND SIM.SIMILAR_HOTEL_SIMILARITY >= 0.6 THEN DENSE_RANK() OVER (PARTITION BY SIM.HOTEL_ID ORDER BY SIM.SIMILAR_HOTEL_SIMILARITY DESC) ELSE 0 END *1 AS RANG_4 , CASE WHEN SIM.SIMILAR_HOTEL_DISTANCE_KM <= 5 AND SIM.SIMILAR_HOTEL_DISTANCE_KM > 3 AND SIM.SIMILAR_HOTEL_SIMILARITY >= 0.6 THEN DENSE_RANK() OVER (PARTITION BY SIM.HOTEL_ID ORDER BY SIM.SIMILAR_HOTEL_SIMILARITY DESC) ELSE 0 END *100 AS RANG_5 , CASE WHEN SIM.SIMILAR_HOTEL_DISTANCE_KM <= 7 AND SIM.SIMILAR_HOTEL_DISTANCE_KM > 5 AND SIM.SIMILAR_HOTEL_SIMILARITY >= 0.6 THEN DENSE_RANK() OVER (PARTITION BY SIM.HOTEL_ID ORDER BY SIM.SIMILAR_HOTEL_SIMILARITY DESC) ELSE 0 END *10000 AS RANG_6 , CASE WHEN SIM.SIMILAR_HOTEL_DISTANCE_KM <= 10 AND SIM.SIMILAR_HOTEL_DISTANCE_KM > 7 AND SIM.SIMILAR_HOTEL_SIMILARITY >= 0.6 THEN DENSE_RANK() OVER (PARTITION BY SIM.HOTEL_ID ORDER BY SIM.SIMILAR_HOTEL_SIMILARITY DESC) ELSE 0 END *1000000 AS RANG_7 , CASE WHEN SIM.SIMILAR_HOTEL_SIMILARITY < 0.6 OR LOCAL.SIMILAR_HOTEL_DISTANCE_KM > 10 THEN DENSE_RANK() OVER (PARTITION BY SIM.HOTEL_ID ORDER BY SIM.SIMILAR_HOTEL_SIMILARITY DESC) ELSE 0 END *100000000 AS RANG_8 , LOCAL.RANG_1 + LOCAL.RANG_2 + LOCAL.RANG_3 + RANG_4+ RANG_5+ RANG_6+ RANG_7+ RANG_8 AS RANG_TOTAL , 0 AS SRC FROM DWHBIL.V_REL_HOTEL_SIMILAR_HOTEL SIM JOIN ORIGHOTEL OH ON SIM.HOTEL_ID=OH.HOTEL_ID JOIN DWHBIL.V_LKP_HOTEL H ON H.HOTEL_ID=SIM.HOTEL_ID AND H.HOTEL_STATUS NOT IN (2) LEFT JOIN DWHBIL.REL_MANUALLY_HOTEL_COMPETITOR_SET M ON M.HOTEL_ID = SIM.HOTEL_ID AND M.SIMILAR_HOTEL_ID = SIM.SIMILAR_HOTEL_ID AND ACTIVE = 1 WHERE 1=1 AND SIM.HOTEL_ID<>SIM.SIMILAR_HOTEL_ID AND M.SIMILAR_HOTEL_ID IS NULL AND SIM.SIMILAR_HOTEL_SIMILARITY>=0.6 AND SIM.SIMILAR_HOTEL_DISTANCE_KM<=10 UNION SELECT RM.HOTEL_ID , RM.SIMILAR_HOTEL_ID , 1 AS SIMILAR_HOTEL_SIMILARITY , 0 AS SIMILAR_HOTEL_DISTANCE_KM , 0 AS RANG_1 , 0 AS RANG_2 , 0 AS RANG_3 , 0 AS RANG_4 , 0 AS RANG_5 , 0 AS RANG_6 , 0 AS RANG_7 , 0 AS RANG_8 , RM.RANG * 0.00000001 AS RANG_TOTAL, 1 AS SRC FROM DWHBIL.REL_MANUALLY_HOTEL_COMPETITOR_SET RM JOIN ORIGHOTEL OH ON RM.HOTEL_ID=OH.HOTEL_ID LEFT JOIN DWHBIL.V_REL_HOTEL_SIMILAR_HOTEL SIM ON RM.HOTEL_ID=SIM.HOTEL_ID AND RM.SIMILAR_HOTEL_ID=SIM.SIMILAR_HOTEL_ID WHERE ACTIVE = 1 ), REPORT_HOTEL_IDS AS ( SELECT RANG.HOTEL_ID, RANG.RANG AS SIMILAR_RANG, RANG.SIMILARITY_TO_REPORT_HOTEL, RANG.DISTANCE_TO_REPORT_HOTEL_KM FROM ( SELECT DISTINCT HOTEL_ID, 0 AS RANG, 1 AS SIMILARITY_TO_REPORT_HOTEL, 0 AS DISTANCE_TO_REPORT_HOTEL_KM FROM ORIGHOTEL UNION ALL SELECT SIMILAR_HOTEL_ID AS HOTEL_ID, DENSE_RANK() OVER (PARTITION BY S.HOTEL_ID ORDER BY RANG_TOTAL) AS RANG, SIMILAR_HOTEL_SIMILARITY AS SIMILARITY_TO_REPORT_HOTEL, SIMILAR_HOTEL_DISTANCE_KM AS DISTANCE_TO_REPORT_HOTEL_KM FROM SIMHOTELS S ) LOCAL.RANG CROSS JOIN ( SELECT CASE WHEN MAX(SIMILAR_HOTEL_SIMILARITY)=1 THEN 7 ELSE 30 END AS NUMBER_BENCHMARK_HOTELS FROM SIMHOTELS ) NUMBER_BM_HOTELS WHERE NUMBER_BM_HOTELS.NUMBER_BENCHMARK_HOTELS>=RANG.RANG ORDER  ...
